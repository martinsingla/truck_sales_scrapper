# %%
import pandas as pd
import pymongo

# %%
#Set connection with MongoDB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'mexican_truckDB' database in Mongo
db = client.mexican_truckDB

# %%
records= db.sales.find()
records= list(records)

# %%
records
# Out:
# [{'_id': ObjectId('6223b90d10c2cf05077f6e1f'),
#   'date': '2007-01-01',
#   'sales': {'truck4_5_ANPACT': nan,
#    'truck6': nan,
#    'truck7': nan,
#    'truckTractor': 989.0,
#    'bus5_6': nan,
#    'bus7': nan,
#    'bus8': nan,
#    'busLongDist': nan},
#   'date_added': '20220305132501'},
#  {'_id': ObjectId('6223b90e10c2cf05077f6e20'),
#   'date': '2007-02-01',
#   'sales': {'truck4_5_ANPACT': nan,
#    'truck6': nan,
#    'truck7': nan,
#    'truckTractor': 1032.0,
#    'bus5_6': nan,
#    'bus7': nan,
#    'bus8': nan,
#    'busLongDist': nan},
#   'date_added': '20220305132502'},
#  {'_id': ObjectId('6223b90e10c2cf05077f6e21'),
#   'date': '2007-03-01',
#   'sales': {'truck4_5_ANPACT': nan,
#    'truck6': nan,
#    'truck7': nan,
#    'truckTractor': 1075.0,
#    'bus5_6': nan,
#    'bus7': nan,
#    'bus8': nan,
#    'busLongDist': nan},
#   'date_added': '20220305132502'},
#  {'_id': ObjectId('6223b90e10c2cf05077f6e22'),
#   'date': '2007-04-01',
# ...

# %%
records[0]['date']
records[0]['sales']['truck4_5_ANPACT']
records[0]['sales']['truck6']
records[0]['sales']['truck7']
records[0]['sales']['truckTractor']
records[0]['sales']['bus5_6']
records[0]['sales']['bus7']
records[0]['sales']['bus8']
records[0]['sales']['busLongDist']
# Out:
# {'truck4_5_ANPACT': nan,
#  'truck6': nan,
#  'truck7': nan,
#  'truckTractor': 989.0,
#  'bus5_6': nan,
#  'bus7': nan,
#  'bus8': nan,
#  'busLongDist': nan}
